# %% [markdown]
# <a href="https://colab.research.google.com/github/Maggismari/Tol0176Anki/blob/main/T%C3%B6l0176ANKI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install genanki

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 1')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er meðaltal (mean)?",
        "svar": "Meðaltal er summa allra talna deilt með fjölda talna. Dæmi: Meðaltal talnanna 3, 5 og 7 er (3+5+7)/3 = 5. Formúla: \\( \\bar{X} = \\frac{\\sum X_i}{n} \\)"
    },
    {
        "spurning": "Hvað er dreifni (variance)?",
        "svar": "Dreifni mælir breytileika talna frá meðaltalinu. Dæmi: Ef talnasettið er 3, 5, 7 þá er dreifnin (1.33) reiknuð með formúlunni \\( s^2 = \\frac{\\sum (X_i - \\bar{X})^2}{n - 1} \\)."
    },
    {
        "spurning": "Hvað er staðalfrávik (standard deviation)?",
        "svar": "Staðalfrávik er ferkvaðarrót dreifni og gefur til kynna meðalfrávik frá meðaltalinu. Dæmi: Ef dreifnin er 4 þá er staðalfrávikið √4 = 2. Formúla: \\( s = \\sqrt{s^2} \\)"
    },
    {
        "spurning": "Hvað er mismunskor (difference score)?",
        "svar": "Mismunskor er munurinn á tveimur mælingum fyrir sama þátttakanda. Dæmi: Ef einkunn fyrir og eftir inngrip er 80 og 85, þá er mismunskor 85 - 80 = 5."
    },
    {
        "spurning": "Hvað er meðaltal mismunskora (\\( M_D \\))?",
        "svar": "Meðaltal mismunskora er meðaltal allra mismunskora. Dæmi: Ef mismunskorin eru 2, 4, 6 þá er meðaltalið (2+4+6)/3 = 4. Formúla: \\( M_D = \\frac{\\sum D}{n} \\)"
    },
    {
        "spurning": "Hvað er summa fervika (sum of squares, SS)?",
        "svar": "Summa fervika er summa allra fervika frá meðaltalinu. Dæmi: Fyrir talnasettið 2, 4, 6 og meðaltal 4, þá er SS = (2-4)^2 + (4-4)^2 + (6-4)^2 = 8. Formúla: \\( SS = \\sum (X_i - \\bar{X})^2 \\) eða \\( SS = \\sum D^2 - \\frac{(\\sum D)^2}{n} \\)"
    },
    {
        "spurning": "Hvað er úrtaksdreifni mismunskora (\\( s_D^2 \\))?",
        "svar": "Úrtaksdreifni mismunskora er dreifni mismunskora innan úrtaks. Dæmi: Ef SS er 8 og n er 4 þá er dreifnin 8/(4-1) = 2.67. Formúla: \\( s_D^2 = \\frac{SS}{n-1} \\)"
    },
    {
        "spurning": "Hvað er staðalvilla mismunskora (\\( s_{M_D} \\))?",
        "svar": "Staðalvilla mismunskora er staðalfrávik meðaltalsdreifingar mismunskora. Dæmi: Ef dreifnin er 2.67 og n er 3 þá er staðalvillan √(2.67/3) = 0.94. Formúla: \\( s_{M_D} = \\sqrt{\\frac{s_D^2}{n}} \\)"
    },
    {
        "spurning": "Hvað er t-gildi (t-value)?",
        "svar": "t-gildi er notað til að bera saman meðaltöl tveggja hópa eða meðaltal við þekkt gildi. Dæmi: Ef meðaltal mismunskora er 5 og staðalvilla er 1 þá er t-gildi 5/1 = 5. Formúla fyrir parað t-próf: \\( t = \\frac{M_D}{s_{M_D}} \\)"
    },
    {
        "spurning": "Hvað eru frígráður (degrees of freedom, df)?",
        "svar": "Fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Dæmi: Fyrir úrtak með 10 þátttakendum er df = 10-1 = 9."
    },
    {
        "spurning": "Hvað er marktektargildi (critical value, \\( t_{crit} \\))?",
        "svar": "Gildi sem skilgreinir mörk þar sem t-próf verður marktækt. Fer eftir \\( \\alpha \\) stigi og frígráðum. Notað úr töflu fyrir t-dreifingu."
    },
    {
        "spurning": "Hvað eru öryggismörk (confidence interval, CI)?",
        "svar": "Bil sem með ákveðinni vissu inniheldur þýðismeðaltal. Dæmi: Fyrir meðaltal mismunskora 5, t-crit 2 og staðalvillu 1, þá eru öryggismörkin 5 ± 2*1, sem gefur bil frá 3 til 7. Formúla: \\( M_D \\pm t_{crit} \\cdot s_{M_D} \\)"
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_1.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_1.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_1.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 2')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er tíðnidreifing (frequency distribution)?",
        "svar": "Tíðnidreifing sýnir hversu oft hvert gildi kemur fyrir í gagnasafni. Dæmi: Í gagnasafni með gildunum 1, 2, 2, 3 er tíðnidreifingin: 1 (1x), 2 (2x), 3 (1x)."
    },
    {
        "spurning": "Hvað er hlutfallstíðni (relative frequency)?",
        "svar": "Hlutfallstíðni er hlutfall hvers gilda miðað við heildarfjölda. Dæmi: Ef gagnasafnið er 1, 2, 2, 3 þá er hlutfallstíðni gildisins 2: 2/4 = 0.5 eða 50%."
    },
    {
        "spurning": "Hvað er safntíðni (cumulative frequency)?",
        "svar": "Safntíðni er summa tíðni fyrir öll gildi minni eða jöfn tilteknu gildi. Dæmi: Fyrir gagnasafnið 1, 2, 2, 3 er safntíðni fyrir 2: 1 (fyrir 1) + 2 (fyrir 2) = 3."
    },
    {
        "spurning": "Hvað er tíðnistíll (histogram)?",
        "svar": "Tíðnistíll er myndræn framsetning tíðnidreifingar með súlum. Hver súla táknar tíðni fyrir ákveðið bil eða gildi. Dæmi: Histogram fyrir gagnasafnið 1, 2, 2, 3 myndi hafa súlur fyrir 1, 2, og 3 með hæðirnar 1, 2, og 1."
    },
    {
        "spurning": "Hvað er tíðarit (frequency polygon)?",
        "svar": "Tíðarit er myndræn framsetning tíðnidreifingar þar sem tíðnir eru tengdar með línum. Dæmi: Fyrir gagnasafnið 1, 2, 2, 3 væri tíðarit með punkta fyrir tíðni 1, 2 og 3 tengda með línum."
    },
    {
        "spurning": "Hvað er spönn (range)?",
        "svar": "Spönn er munurinn á hæsta og lægsta gildi í gagnasafni. Dæmi: Fyrir gagnasafnið 1, 2, 2, 3 er spönnin 3 - 1 = 2."
    },
    {
        "spurning": "Hvað er meðaltal (mean)?",
        "svar": "Meðaltal er summa allra gilda deilt með fjölda gilda. Dæmi: Fyrir gagnasafnið 1, 2, 2, 3 er meðaltalið (1+2+2+3)/4 = 2."
    },
    {
        "spurning": "Hvað er miðgildi (median)?",
        "svar": "Miðgildi er miðju gildi í röðuðu gagnasafni. Dæmi: Fyrir gagnasafnið 1, 2, 2, 3 er miðgildið 2."
    },
    {
        "spurning": "Hvað er tíðasta gildi (mode)?",
        "svar": "Tíðasta gildi er það gildi sem kemur oftast fyrir í gagnasafni. Dæmi: Fyrir gagnasafnið 1, 2, 2, 3 er tíðasta gildið 2."
    },
    {
        "spurning": "Hvað er frávik (deviation)?",
        "svar": "Frávik er munurinn á tilteknu gildi og meðaltali gagnasafns. Dæmi: Ef meðaltalið er 2 og gildi er 3 þá er frávikið 3 - 2 = 1."
    },
    {
        "spurning": "Hvað er dreifni (variance)?",
        "svar": "Dreifni mælir hversu mikið gildin í gagnasafni dreifast frá meðaltalinu. Dæmi: Fyrir gagnasafnið 1, 2, 2, 3 er dreifnin reiknuð með formúlunni \\( s^2 = \\frac{\\sum (X_i - \\bar{X})^2}{n - 1} \\)."
    },
    {
        "spurning": "Hvað er staðalfrávik (standard deviation)?",
        "svar": "Staðalfrávik er ferkvaðarrót dreifni og gefur til kynna meðalfrávik frá meðaltalinu. Dæmi: Ef dreifnin er 4 þá er staðalfrávikið √4 = 2. Formúla: \\( s = \\sqrt{s^2} \\)"
    },
    {
        "spurning": "Hvað er normalkúrfan (normal curve)?",
        "svar": "Normalkúrfan er bjöllulaga kúrfa sem táknar normaldreifingu, þar sem flest gildi eru nálægt meðaltalinu. Dæmi: Hæð fólks er oft dreifð samkvæmt normalkúrfu."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_2.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_2.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_2.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 3')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er miðsækni (central tendency)?",
        "svar": "Miðsækni er mælikvarði á miðju dreifingar. Helstu mælikvarðar eru meðaltal, miðgildi og tíðasta gildi."
    },
    {
        "spurning": "Hvað er meðaltal (mean)?",
        "svar": "Meðaltal er summa allra gilda deilt með fjölda gilda. Dæmi: Fyrir gagnasafnið 1, 2, 3 er meðaltalið (1+2+3)/3 = 2."
    },
    {
        "spurning": "Hvað er miðgildi (median)?",
        "svar": "Miðgildi er miðju gildi í röðuðu gagnasafni. Dæmi: Fyrir gagnasafnið 1, 2, 3 er miðgildið 2."
    },
    {
        "spurning": "Hvað er tíðasta gildi (mode)?",
        "svar": "Tíðasta gildi er það gildi sem kemur oftast fyrir í gagnasafni. Dæmi: Fyrir gagnasafnið 1, 2, 2, 3 er tíðasta gildið 2."
    },
    {
        "spurning": "Hvað er frávik (deviation)?",
        "svar": "Frávik er munurinn á tilteknu gildi og meðaltali gagnasafns. Dæmi: Ef meðaltalið er 2 og gildi er 3 þá er frávikið 3 - 2 = 1."
    },
    {
        "spurning": "Hvað er dreifni (variance)?",
        "svar": "Dreifni mælir hversu mikið gildin í gagnasafni dreifast frá meðaltalinu. Dæmi: Fyrir gagnasafnið 1, 2, 3 er dreifnin reiknuð með formúlunni \\( s^2 = \\frac{\\sum (X_i - \\bar{X})^2}{n - 1} \\)."
    },
    {
        "spurning": "Hvað er staðalfrávik (standard deviation)?",
        "svar": "Staðalfrávik er ferkvaðarrót dreifni og gefur til kynna meðalfrávik frá meðaltalinu. Dæmi: Ef dreifnin er 4 þá er staðalfrávikið √4 = 2. Formúla: \\( s = \\sqrt{s^2} \\)"
    },
    {
        "spurning": "Hvað er normalkúrfan (normal curve)?",
        "svar": "Normalkúrfan er bjöllulaga kúrfa sem táknar normaldreifingu, þar sem flest gildi eru nálægt meðaltalinu. Dæmi: Hæð fólks er oft dreifð samkvæmt normalkúrfu."
    },
    {
        "spurning": "Hvað er bjögun (skewness)?",
        "svar": "Bjögun mælir ósamhverfu dreifingar. Ef hala dreifingarinnar er lengri á hægri eða vinstri hlið, þá er dreifingin sögð vera hægri eða vinstri bjöguð."
    },
    {
        "spurning": "Hvað er ris (kurtosis)?",
        "svar": "Ris mælir hversu mikið gildi dreifingarinnar eru þjappuð saman við miðju eða dreifast út í hala. Hátt ris bendir til þess að dreifingin hafi þéttan miðju og langa hala."
    },
    {
        "spurning": "Hvað er z-gildi (z-score)?",
        "svar": "z-gildi mælir fjarlægð gildi frá meðaltali í staðalfrávikum. Dæmi: Ef meðaltalið er 100, staðalfrávikið er 15 og gildi er 130, þá er z-gildið (130-100)/15 ≈ 2."
    },
    {
        "spurning": "Hvað er prósentustig (percentile)?",
        "svar": "Prósentustig gefur til kynna stöðu gildi innan dreifingar. Dæmi: Ef gildi er á 90. prósentustigi, þá eru 90% gilda fyrir neðan það gildi."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_3.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_3.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_3.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 4')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er breytileiki (variability)?",
        "svar": "Breytileiki mælir hversu mikið gildi í gagnasafni dreifast frá meðaltalinu. Helstu mælikvarðar eru spönn, dreifni og staðalfrávik."
    },
    {
        "spurning": "Hvað er spönn (range)?",
        "svar": "Spönn er munurinn á hæsta og lægsta gildi í gagnasafni. Dæmi: Fyrir gagnasafnið 3, 7, 8, 10 er spönnin 10 - 3 = 7."
    },
    {
        "spurning": "Hvað er dreifni (variance)?",
        "svar": "Dreifni mælir hversu mikið gildi í gagnasafni dreifast frá meðaltalinu. Dæmi: Ef talnasettið er 3, 7, 7, 8, 10 þá er dreifnin reiknuð með formúlunni \\( s^2 = \\frac{\\sum (X_i - \\bar{X})^2}{n - 1} \\)."
    },
    {
        "spurning": "Hvað er staðalfrávik (standard deviation)?",
        "svar": "Staðalfrávik er ferkvaðarrót dreifni og gefur til kynna meðalfrávik frá meðaltalinu. Dæmi: Ef dreifnin er 4 þá er staðalfrávikið √4 = 2. Formúla: \\( s = \\sqrt{s^2} \\)"
    },
    {
        "spurning": "Hvað er summan af fervikum (sum of squares, SS)?",
        "svar": "Summan af fervikum er summa allra fervika frá meðaltalinu. Dæmi: Fyrir talnasettið 3, 7, 7, 8, 10 með meðaltalið 7 er SS = (3-7)^2 + (7-7)^2 + (7-7)^2 + (8-7)^2 + (10-7)^2 = 29."
    },
    {
        "spurning": "Hvað er staðalvilla (standard error)?",
        "svar": "Staðalvilla er mat á staðalfráviki úrtaksmeðaltala. Dæmi: Ef staðalfrávik úrtaks er 4 og úrtaksstærð er 16 þá er staðalvillan 4/√16 = 1."
    },
    {
        "spurning": "Hvað er z-gildi (z-score)?",
        "svar": "z-gildi mælir fjarlægð gildi frá meðaltali í staðalfrávikum. Dæmi: Ef meðaltalið er 100, staðalfrávikið er 15 og gildi er 130, þá er z-gildið (130-100)/15 ≈ 2."
    },
    {
        "spurning": "Hvað er dreifing úrtaksmeðaltala (sampling distribution of the mean)?",
        "svar": "Dreifing úrtaksmeðaltala er dreifing meðaltala margra úrtaka úr sama þýði. Hún hefur tilhneigingu til að vera normaldreifð ef úrtökin eru nógu stór."
    },
    {
        "spurning": "Hvað er lögmálið um stóra tölur (law of large numbers)?",
        "svar": "Lögmálið um stóra tölur segir að eftir því sem úrtaksstærðin eykst, mun úrtaksmeðaltalið nálgast þýðismeðaltalið."
    },
    {
        "spurning": "Hvað er miðgildissetningin (central limit theorem)?",
        "svar": "Miðgildissetningin segir að dreifing úrtaksmeðaltala verður normaldreifð ef úrtaksstærðin er nægilega stór, óháð lögun upprunalegu dreifingarinnar."
    },
    {
        "spurning": "Hvað er öryggisbil (confidence interval)?",
        "svar": "Öryggisbil er bil sem, með tiltekinni vissu, inniheldur þýðismeðaltal. Dæmi: Fyrir 95% öryggisbil um meðaltal 50 með staðalvillu 2 er öryggisbilið 50 ± 1.96*2, sem er frá 46.08 til 53.92."
    },
    {
        "spurning": "Hvað er α (alpha)?",
        "svar": "α er marktektarstig, oftast sett sem 0.05. Það er líkurnar á að hafna núlltilgátunni þegar hún er sönn (gerð I villa)."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_4.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_4.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_4.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 5')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er z-gildi (z-score)?",
        "svar": "z-gildi mælir fjarlægð gildi frá meðaltali í staðalfrávikum. Dæmi: Ef meðaltalið er 100, staðalfrávikið er 15 og gildi er 130, þá er z-gildið (130-100)/15 ≈ 2."
    },
    {
        "spurning": "Hvað er staðalfrávik (standard deviation)?",
        "svar": "Staðalfrávik er ferkvaðarrót dreifni og gefur til kynna meðalfrávik frá meðaltalinu. Dæmi: Ef dreifnin er 4 þá er staðalfrávikið √4 = 2. Formúla: \\( s = \\sqrt{s^2} \\)"
    },
    {
        "spurning": "Hvað er dreifing úrtaksmeðaltala (sampling distribution of the mean)?",
        "svar": "Dreifing úrtaksmeðaltala er dreifing meðaltala margra úrtaka úr sama þýði. Hún hefur tilhneigingu til að vera normaldreifð ef úrtökin eru nógu stór."
    },
    {
        "spurning": "Hvað er lögmálið um stóra tölur (law of large numbers)?",
        "svar": "Lögmálið um stóra tölur segir að eftir því sem úrtaksstærðin eykst, mun úrtaksmeðaltalið nálgast þýðismeðaltalið."
    },
    {
        "spurning": "Hvað er miðgildissetningin (central limit theorem)?",
        "svar": "Miðgildissetningin segir að dreifing úrtaksmeðaltala verður normaldreifð ef úrtaksstærðin er nægilega stór, óháð lögun upprunalegu dreifingarinnar."
    },
    {
        "spurning": "Hvað er öryggisbil (confidence interval)?",
        "svar": "Öryggisbil er bil sem, með tiltekinni vissu, inniheldur þýðismeðaltal. Dæmi: Fyrir 95% öryggisbil um meðaltal 50 með staðalvillu 2 er öryggisbilið 50 ± 1.96*2, sem er frá 46.08 til 53.92."
    },
    {
        "spurning": "Hvað er α (alpha)?",
        "svar": "α er marktektarstig, oftast sett sem 0.05. Það er líkurnar á að hafna núlltilgátunni þegar hún er sönn (gerð I villa)."
    },
    {
        "spurning": "Hvað er núlltilgáta (null hypothesis)?",
        "svar": "Núlltilgátan er tilgáta sem segir að enginn marktækur munur sé á milli hópa eða breyta. Hún er oft táknuð sem H0."
    },
    {
        "spurning": "Hvað er gagntilgáta (alternative hypothesis)?",
        "svar": "Gagntilgáta er tilgáta sem segir að það sé marktækur munur á milli hópa eða breyta. Hún er oft táknuð sem H1."
    },
    {
        "spurning": "Hvað er z-próf (z-test)?",
        "svar": "z-próf er notað til að kanna hvort meðaltal úrtaks sé marktækt frábrugðið þýðismeðaltali þegar staðalfrávik þýðis er þekkt."
    },
    {
        "spurning": "Hvað er t-próf (t-test)?",
        "svar": "t-próf er notað til að kanna hvort meðaltal úrtaks sé marktækt frábrugðið þýðismeðaltali þegar staðalfrávik þýðis er ekki þekkt."
    },
    {
        "spurning": "Hvað er einhliða t-próf (one-sample t-test)?",
        "svar": "Einhliða t-próf er notað til að bera saman meðaltal úrtaks við þekkt gildi eða þýðismeðaltal."
    },
    {
        "spurning": "Hvað er tvíhliða t-próf (independent t-test)?",
        "svar": "Tvíhliða t-próf er notað til að bera saman meðaltöl tveggja óháðra hópa."
    },
    {
        "spurning": "Hvað er parað t-próf (paired t-test)?",
        "svar": "Parað t-próf er notað til að bera saman meðaltöl tveggja tengdra mælinga, t.d. fyrir og eftir inngrip."
    },
    {
        "spurning": "Hvað er frígráður (degrees of freedom, df)?",
        "svar": "Fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Dæmi: Fyrir úrtak með 10 þátttakendum er df = 10-1 = 9."
    },
    {
        "spurning": "Hvað er p-gildi (p-value)?",
        "svar": "p-gildi er líkurnar á að fá jafnvel eða öfgafyllri niðurstöðu en þá sem fengist hefur, ef núlltilgátan er sönn. Ef p-gildið er minna en α, hafnar maður núlltilgátunni."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_5.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_5.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_5.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 5')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er z-gildi (z-score)?",
        "svar": "z-gildi mælir fjarlægð gildi frá meðaltali í staðalfrávikum. Dæmi: Ef meðaltalið er 100, staðalfrávikið er 15 og gildi er 130, þá er z-gildið (130-100)/15 ≈ 2."
    },
    {
        "spurning": "Hvað er staðalfrávik (standard deviation)?",
        "svar": "Staðalfrávik er ferkvaðarrót dreifni og gefur til kynna meðalfrávik frá meðaltalinu. Dæmi: Ef dreifnin er 4 þá er staðalfrávikið √4 = 2. Formúla: \\( s = \\sqrt{s^2} \\)"
    },
    {
        "spurning": "Hvað er dreifing úrtaksmeðaltala (sampling distribution of the mean)?",
        "svar": "Dreifing úrtaksmeðaltala er dreifing meðaltala margra úrtaka úr sama þýði. Hún hefur tilhneigingu til að vera normaldreifð ef úrtökin eru nógu stór."
    },
    {
        "spurning": "Hvað er lögmálið um stóra tölur (law of large numbers)?",
        "svar": "Lögmálið um stóra tölur segir að eftir því sem úrtaksstærðin eykst, mun úrtaksmeðaltalið nálgast þýðismeðaltalið."
    },
    {
        "spurning": "Hvað er miðgildissetningin (central limit theorem)?",
        "svar": "Miðgildissetningin segir að dreifing úrtaksmeðaltala verður normaldreifð ef úrtaksstærðin er nægilega stór, óháð lögun upprunalegu dreifingarinnar."
    },
    {
        "spurning": "Hvað er öryggisbil (confidence interval)?",
        "svar": "Öryggisbil er bil sem, með tiltekinni vissu, inniheldur þýðismeðaltal. Dæmi: Fyrir 95% öryggisbil um meðaltal 50 með staðalvillu 2 er öryggisbilið 50 ± 1.96*2, sem er frá 46.08 til 53.92."
    },
    {
        "spurning": "Hvað er α (alpha)?",
        "svar": "α er marktektarstig, oftast sett sem 0.05. Það er líkurnar á að hafna núlltilgátunni þegar hún er sönn (gerð I villa)."
    },
    {
        "spurning": "Hvað er núlltilgáta (null hypothesis)?",
        "svar": "Núlltilgátan er tilgáta sem segir að enginn marktækur munur sé á milli hópa eða breyta. Hún er oft táknuð sem H0."
    },
    {
        "spurning": "Hvað er gagntilgáta (alternative hypothesis)?",
        "svar": "Gagntilgáta er tilgáta sem segir að það sé marktækur munur á milli hópa eða breyta. Hún er oft táknuð sem H1."
    },
    {
        "spurning": "Hvað er z-próf (z-test)?",
        "svar": "z-próf er notað til að kanna hvort meðaltal úrtaks sé marktækt frábrugðið þýðismeðaltali þegar staðalfrávik þýðis er þekkt."
    },
    {
        "spurning": "Hvað er t-próf (t-test)?",
        "svar": "t-próf er notað til að kanna hvort meðaltal úrtaks sé marktækt frábrugðið þýðismeðaltali þegar staðalfrávik þýðis er ekki þekkt."
    },
    {
        "spurning": "Hvað er einhliða t-próf (one-sample t-test)?",
        "svar": "Einhliða t-próf er notað til að bera saman meðaltal úrtaks við þekkt gildi eða þýðismeðaltal."
    },
    {
        "spurning": "Hvað er tvíhliða t-próf (independent t-test)?",
        "svar": "Tvíhliða t-próf er notað til að bera saman meðaltöl tveggja óháðra hópa."
    },
    {
        "spurning": "Hvað er parað t-próf (paired t-test)?",
        "svar": "Parað t-próf er notað til að bera saman meðaltöl tveggja tengdra mælinga, t.d. fyrir og eftir inngrip."
    },
    {
        "spurning": "Hvað er frígráður (degrees of freedom, df)?",
        "svar": "Fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Dæmi: Fyrir úrtak með 10 þátttakendum er df = 10-1 = 9."
    },
    {
        "spurning": "Hvað er p-gildi (p-value)?",
        "svar": "p-gildi er líkurnar á að fá jafnvel eða öfgafyllri niðurstöðu en þá sem fengist hefur, ef núlltilgátan er sönn. Ef p-gildið er minna en α, hafnar maður núlltilgátunni."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_5.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_5.apkg")

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 6')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er líkindafræði (probability theory)?",
        "svar": "Líkindafræði er grein stærðfræðinnar sem fjallar um útreikninga á líkum atburða. Hún hjálpar okkur að skilja og spá fyrir um óvissar útkomur."
    },
    {
        "spurning": "Hvað eru líkur (probability)?",
        "svar": "Líkur eru mælikvarði á möguleika þess að tiltekinn atburður gerist. Þær eru oftast táknaðar sem tala á bilinu 0 til 1 eða sem prósenta."
    },
    {
        "spurning": "Hvað er úrtak (sample)?",
        "svar": "Úrtak er hluti af þýði sem valið er til að draga ályktanir um þýðið í heild. Úrtakið ætti að vera dæmigert fyrir þýðið."
    },
    {
        "spurning": "Hvað er þýði (population)?",
        "svar": "Þýði er heildarsafn allra eininga sem við viljum rannsaka eða draga ályktanir um. Dæmi: Allir nemendur í skóla geta verið þýði."
    },
    {
        "spurning": "Hvað er líkindadreifing (probability distribution)?",
        "svar": "Líkindadreifing sýnir hvernig líkur dreifast yfir mögulegar útkomur tiltekins tilraunar. Dæmi: Normalkúrfa er dæmi um líkindadreifingu."
    },
    {
        "spurning": "Hvað er normaldreifing (normal distribution)?",
        "svar": "Normaldreifing er bjöllulaga, samhverf dreifing sem er algeng í tölfræði. Hún er einnig kölluð Gauss-dreifing. Dæmi: Hæð fólks fylgir oft normaldreifingu."
    },
    {
        "spurning": "Hvað er z-gildi (z-score)?",
        "svar": "z-gildi mælir fjarlægð gildi frá meðaltali í staðalfrávikum. Dæmi: Ef meðaltalið er 100, staðalfrávikið er 15 og gildi er 130, þá er z-gildið (130-100)/15 ≈ 2."
    },
    {
        "spurning": "Hvað er lögmálið um stórar tölur (law of large numbers)?",
        "svar": "Lögmálið um stórar tölur segir að eftir því sem úrtaksstærðin eykst, mun meðaltal úrtaksins nálgast þýðismeðaltalið."
    },
    {
        "spurning": "Hvað er miðgildissetningin (central limit theorem)?",
        "svar": "Miðgildissetningin segir að dreifing úrtaksmeðaltala verður normaldreifð ef úrtaksstærðin er nægilega stór, óháð lögun upprunalegu dreifingarinnar."
    },
    {
        "spurning": "Hvað er öryggisbil (confidence interval)?",
        "svar": "Öryggisbil er bil sem, með tiltekinni vissu, inniheldur þýðismeðaltal. Dæmi: Fyrir 95% öryggisbil um meðaltal 50 með staðalvillu 2 er öryggisbilið 50 ± 1.96*2, sem er frá 46.08 til 53.92."
    },
    {
        "spurning": "Hvað er α (alpha)?",
        "svar": "α er marktektarstig, oftast sett sem 0.05. Það er líkurnar á að hafna núlltilgátunni þegar hún er sönn (gerð I villa)."
    },
    {
        "spurning": "Hvað er núlltilgáta (null hypothesis)?",
        "svar": "Núlltilgátan er tilgáta sem segir að enginn marktækur munur sé á milli hópa eða breyta. Hún er oft táknuð sem H0."
    },
    {
        "spurning": "Hvað er gagntilgáta (alternative hypothesis)?",
        "svar": "Gagntilgáta er tilgáta sem segir að það sé marktækur munur á milli hópa eða breyta. Hún er oft táknuð sem H1."
    },
    {
        "spurning": "Hvað er marktektarpróf (significance test)?",
        "svar": "Marktektarpróf er aðferð til að kanna hvort niðurstöður rannsókna séu marktækar, þ.e. hvort þær séu ólíklegar að hafa komið fyrir vegna tilviljunar. Dæmi: t-próf eða z-próf."
    },
    {
        "spurning": "Hvað er p-gildi (p-value)?",
        "svar": "p-gildi er líkurnar á að fá jafnvel eða öfgafyllri niðurstöðu en þá sem fengist hefur, ef núlltilgátan er sönn. Ef p-gildið er minna en α, hafnar maður núlltilgátunni."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_6.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_6.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_6.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 7')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er dreifing úrtaksmeðaltala (sampling distribution of the sample mean)?",
        "svar": "Dreifing úrtaksmeðaltala er dreifing meðaltala margra úrtaka úr sama þýði. Hún hefur tilhneigingu til að vera normaldreifð ef úrtökin eru nógu stór."
    },
    {
        "spurning": "Hvað er staðalvilla úrtaksmeðaltala (standard error of the mean)?",
        "svar": "Staðalvilla úrtaksmeðaltala er mat á staðalfráviki úrtaksmeðaltala. Dæmi: Ef staðalfrávik úrtaks er 4 og úrtaksstærð er 16 þá er staðalvillan 4/√16 = 1."
    },
    {
        "spurning": "Hvað er lögmálið um stórar tölur (law of large numbers)?",
        "svar": "Lögmálið um stórar tölur segir að eftir því sem úrtaksstærðin eykst, mun meðaltal úrtaksins nálgast þýðismeðaltalið."
    },
    {
        "spurning": "Hvað er miðgildissetningin (central limit theorem)?",
        "svar": "Miðgildissetningin segir að dreifing úrtaksmeðaltala verður normaldreifð ef úrtaksstærðin er nægilega stór, óháð lögun upprunalegu dreifingarinnar."
    },
    {
        "spurning": "Hvað er öryggisbil (confidence interval)?",
        "svar": "Öryggisbil er bil sem, með tiltekinni vissu, inniheldur þýðismeðaltal. Dæmi: Fyrir 95% öryggisbil um meðaltal 50 með staðalvillu 2 er öryggisbilið 50 ± 1.96*2, sem er frá 46.08 til 53.92."
    },
    {
        "spurning": "Hvað er z-gildi (z-score)?",
        "svar": "z-gildi mælir fjarlægð gildi frá meðaltali í staðalfrávikum. Dæmi: Ef meðaltalið er 100, staðalfrávikið er 15 og gildi er 130, þá er z-gildið (130-100)/15 ≈ 2."
    },
    {
        "spurning": "Hvað er α (alpha)?",
        "svar": "α er marktektarstig, oftast sett sem 0.05. Það er líkurnar á að hafna núlltilgátunni þegar hún er sönn (gerð I villa)."
    },
    {
        "spurning": "Hvað er núlltilgáta (null hypothesis)?",
        "svar": "Núlltilgátan er tilgáta sem segir að enginn marktækur munur sé á milli hópa eða breyta. Hún er oft táknuð sem H0."
    },
    {
        "spurning": "Hvað er gagntilgáta (alternative hypothesis)?",
        "svar": "Gagntilgáta er tilgáta sem segir að það sé marktækur munur á milli hópa eða breyta. Hún er oft táknuð sem H1."
    },
    {
        "spurning": "Hvað er marktektarpróf (significance test)?",
        "svar": "Marktektarpróf er aðferð til að kanna hvort niðurstöður rannsókna séu marktækar, þ.e. hvort þær séu ólíklegar að hafa komið fyrir vegna tilviljunar. Dæmi: t-próf eða z-próf."
    },
    {
        "spurning": "Hvað er p-gildi (p-value)?",
        "svar": "p-gildi er líkurnar á að fá jafnvel eða öfgafyllri niðurstöðu en þá sem fengist hefur, ef núlltilgátan er sönn. Ef p-gildið er minna en α, hafnar maður núlltilgátunni."
    },
    {
        "spurning": "Hvað er t-gildi (t-value)?",
        "svar": "t-gildi er notað til að bera saman meðaltöl tveggja hópa eða meðaltal við þekkt gildi. Dæmi: Ef meðaltal mismunskora er 5 og staðalvilla er 1 þá er t-gildi 5/1 = 5."
    },
    {
        "spurning": "Hvað eru frígráður (degrees of freedom, df)?",
        "svar": "Fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Dæmi: Fyrir úrtak með 10 þátttakendum er df = 10-1 = 9."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_7.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_7.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_7.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 8')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er tilgátuprófun (hypothesis testing)?",
        "svar": "Tilgátuprófun er aðferð til að meta hvort gögn styðji tilgátu eða ekki. Þetta ferli felur í sér að setja fram núlltilgátu og gagntilgátu, reikna prófstærð, og bera hana saman við marktektarmörk til að ákveða hvort hafna eigi núlltilgátunni."
    },
    {
        "spurning": "Hvað er núlltilgáta (null hypothesis)?",
        "svar": "Núlltilgátan (H0) er tilgáta sem segir að enginn marktækur munur eða samband sé til staðar. Dæmi: H0: Meðaltal hóps A er jafnt meðaltali hóps B."
    },
    {
        "spurning": "Hvað er gagntilgáta (alternative hypothesis)?",
        "svar": "Gagntilgátan (H1) er tilgáta sem segir að það sé marktækur munur eða samband til staðar. Dæmi: H1: Meðaltal hóps A er ekki jafnt meðaltali hóps B."
    },
    {
        "spurning": "Hvað er α (alpha)?",
        "svar": "α (alpha) er marktektarstig, oftast sett sem 0.05. Það er líkurnar á að hafna núlltilgátunni þegar hún er sönn (gerð I villa)."
    },
    {
        "spurning": "Hvað er p-gildi (p-value)?",
        "svar": "p-gildi er líkurnar á að fá jafnvel eða öfgafyllri niðurstöðu en þá sem fengist hefur, ef núlltilgátan er sönn. Ef p-gildið er minna en α, hafnar maður núlltilgátunni."
    },
    {
        "spurning": "Hvað er gerð I villa (Type I error)?",
        "svar": "Gerð I villa á sér stað þegar núlltilgátunni er hafnað þegar hún er í raun sönn. Líkurnar á að gera gerð I villu eru táknaðar með α."
    },
    {
        "spurning": "Hvað er gerð II villa (Type II error)?",
        "svar": "Gerð II villa á sér stað þegar núlltilgátunni er ekki hafnað þegar hún er í raun ósönn. Líkurnar á að gera gerð II villu eru táknaðar með β."
    },
    {
        "spurning": "Hvað er afköst (power) í tilgátuprófun?",
        "svar": "Afköst (1-β) er líkurnar á að hafna núlltilgátunni þegar hún er í raun ósönn. Afköst eru mælikvarði á næmni prófsins til að greina raunverulegan mun eða samband."
    },
    {
        "spurning": "Hvað er z-próf (z-test)?",
        "svar": "z-próf er notað til að kanna hvort meðaltal úrtaks sé marktækt frábrugðið þýðismeðaltali þegar staðalfrávik þýðis er þekkt. Dæmi: Notað þegar úrtaksstærðin er stór (n > 30)."
    },
    {
        "spurning": "Hvað er t-próf (t-test)?",
        "svar": "t-próf er notað til að kanna hvort meðaltal úrtaks sé marktækt frábrugðið þýðismeðaltali þegar staðalfrávik þýðis er ekki þekkt. Dæmi: Notað þegar úrtaksstærðin er lítil (n ≤ 30)."
    },
    {
        "spurning": "Hvað er einhliða t-próf (one-sample t-test)?",
        "svar": "Einhliða t-próf er notað til að bera saman meðaltal úrtaks við þekkt gildi eða þýðismeðaltal. Dæmi: Kanna hvort meðaltal hæðar í úrtaki sé 170 cm."
    },
    {
        "spurning": "Hvað er tvíhliða t-próf (independent t-test)?",
        "svar": "Tvíhliða t-próf er notað til að bera saman meðaltöl tveggja óháðra hópa. Dæmi: Kanna hvort munur sé á meðaltalshæð karla og kvenna."
    },
    {
        "spurning": "Hvað er parað t-próf (paired t-test)?",
        "svar": "Parað t-próf er notað til að bera saman meðaltöl tveggja tengdra mælinga, t.d. fyrir og eftir inngrip. Dæmi: Kanna áhrif meðferðar á blóðþrýsting fyrir og eftir meðferð."
    },
    {
        "spurning": "Hvað eru frígráður (degrees of freedom, df)?",
        "svar": "Frígráður eru fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Dæmi: Fyrir úrtak með 10 þátttakendum er df = 10-1 = 9."
    },
    {
        "spurning": "Hvað er dreifing úrtaksmeðaltala (sampling distribution of the sample mean)?",
        "svar": "Dreifing úrtaksmeðaltala er dreifing meðaltala margra úrtaka úr sama þýði. Hún hefur tilhneigingu til að vera normaldreifð ef úrtökin eru nógu stór."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_8.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_8.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_8.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 9')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er t-próf (t-test)?",
        "svar": "t-próf er notað til að kanna hvort meðaltal úrtaks sé marktækt frábrugðið þýðismeðaltali þegar staðalfrávik þýðis er ekki þekkt. Dæmi: Notað þegar úrtaksstærðin er lítil (n ≤ 30)."
    },
    {
        "spurning": "Hvað er einhliða t-próf (one-sample t-test)?",
        "svar": "Einhliða t-próf er notað til að bera saman meðaltal úrtaks við þekkt gildi eða þýðismeðaltal. Dæmi: Kanna hvort meðaltal hæðar í úrtaki sé 170 cm."
    },
    {
        "spurning": "Hvað er tvíhliða t-próf (independent t-test)?",
        "svar": "Tvíhliða t-próf er notað til að bera saman meðaltöl tveggja óháðra hópa. Dæmi: Kanna hvort munur sé á meðaltalshæð karla og kvenna."
    },
    {
        "spurning": "Hvað er parað t-próf (paired t-test)?",
        "svar": "Parað t-próf er notað til að bera saman meðaltöl tveggja tengdra mælinga, t.d. fyrir og eftir inngrip. Dæmi: Kanna áhrif meðferðar á blóðþrýsting fyrir og eftir meðferð."
    },
    {
        "spurning": "Hvað er frígráður (degrees of freedom, df)?",
        "svar": "Frígráður eru fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Dæmi: Fyrir úrtak með 10 þátttakendum er df = 10-1 = 9."
    },
    {
        "spurning": "Hvað er marktektarstig (significance level, α)?",
        "svar": "Marktektarstig (α) er sá þröskuldur sem ákveðinn er fyrirfram og segir til um hversu miklar líkur mega vera á að hafna núlltilgátunni þegar hún er sönn. Algengt marktektarstig er 0.05."
    },
    {
        "spurning": "Hvað er p-gildi (p-value)?",
        "svar": "p-gildi er líkurnar á að fá jafnvel eða öfgafyllri niðurstöðu en þá sem fengist hefur, ef núlltilgátan er sönn. Ef p-gildið er minna en α, hafnar maður núlltilgátunni."
    },
    {
        "spurning": "Hvað er Cohen's d?",
        "svar": "Cohen's d er mælikvarði á áhrifastærð. Hann gefur til kynna hversu mikill munur er á milli hópa í staðalfrávikum. Dæmi: d = 0.2 (lítil áhrif), d = 0.5 (miðlungs áhrif), d = 0.8 (mikil áhrif)."
    },
    {
        "spurning": "Hvað er áhrifastærð (effect size)?",
        "svar": "Áhrifastærð mælir styrkleika sambandsins eða muninn á milli hópa. Hún gefur til kynna hversu mikill praktískur munur er, óháð marktekt. Dæmi: Cohen's d, Pearson's r."
    },
    {
        "spurning": "Hvað er öryggisbil (confidence interval)?",
        "svar": "Öryggisbil er bil sem, með tiltekinni vissu, inniheldur þýðismeðaltal eða annan þýðisparameter. Dæmi: Fyrir 95% öryggisbil um meðaltal 50 með staðalvillu 2 er öryggisbilið 50 ± 1.96*2, sem er frá 46.08 til 53.92."
    },
    {
        "spurning": "Hvað er núlltilgáta (null hypothesis)?",
        "svar": "Núlltilgátan (H0) er tilgáta sem segir að enginn marktækur munur eða samband sé til staðar. Dæmi: H0: Meðaltal hóps A er jafnt meðaltali hóps B."
    },
    {
        "spurning": "Hvað er gagntilgáta (alternative hypothesis)?",
        "svar": "Gagntilgátan (H1) er tilgáta sem segir að það sé marktækur munur eða samband til staðar. Dæmi: H1: Meðaltal hóps A er ekki jafnt meðaltali hóps B."
    },
    {
        "spurning": "Hvað er gerð I villa (Type I error)?",
        "svar": "Gerð I villa á sér stað þegar núlltilgátunni er hafnað þegar hún er í raun sönn. Líkurnar á að gera gerð I villu eru táknaðar með α."
    },
    {
        "spurning": "Hvað er gerð II villa (Type II error)?",
        "svar": "Gerð II villa á sér stað þegar núlltilgátunni er ekki hafnað þegar hún er í raun ósönn. Líkurnar á að gera gerð II villu eru táknaðar með β."
    },
    {
        "spurning": "Hvað er afköst (power) í tilgátuprófun?",
        "svar": "Afköst (1-β) er líkurnar á að hafna núlltilgátunni þegar hún er í raun ósönn. Afköst eru mælikvarði á næmni prófsins til að greina raunverulegan mun eða samband."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_9.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_9.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_9.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 10')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er t-próf (t-test)?",
        "svar": "t-próf er notað til að kanna hvort meðaltal úrtaks sé marktækt frábrugðið þýðismeðaltali þegar staðalfrávik þýðis er ekki þekkt. Dæmi: Notað þegar úrtaksstærðin er lítil (n ≤ 30)."
    },
    {
        "spurning": "Hvað er einhliða t-próf (one-sample t-test)?",
        "svar": "Einhliða t-próf er notað til að bera saman meðaltal úrtaks við þekkt gildi eða þýðismeðaltal. Dæmi: Kanna hvort meðaltal hæðar í úrtaki sé 170 cm."
    },
    {
        "spurning": "Hvað er tvíhliða t-próf (independent t-test)?",
        "svar": "Tvíhliða t-próf er notað til að bera saman meðaltöl tveggja óháðra hópa. Dæmi: Kanna hvort munur sé á meðaltalshæð karla og kvenna."
    },
    {
        "spurning": "Hvað er parað t-próf (paired t-test)?",
        "svar": "Parað t-próf er notað til að bera saman meðaltöl tveggja tengdra mælinga, t.d. fyrir og eftir inngrip. Dæmi: Kanna áhrif meðferðar á blóðþrýsting fyrir og eftir meðferð."
    },
    {
        "spurning": "Hvað er frígráður (degrees of freedom, df)?",
        "svar": "Frígráður eru fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Dæmi: Fyrir úrtak með 10 þátttakendum er df = 10-1 = 9."
    },
    {
        "spurning": "Hvað er marktektarstig (significance level, α)?",
        "svar": "Marktektarstig (α) er sá þröskuldur sem ákveðinn er fyrirfram og segir til um hversu miklar líkur mega vera á að hafna núlltilgátunni þegar hún er sönn. Algengt marktektarstig er 0.05."
    },
    {
        "spurning": "Hvað er p-gildi (p-value)?",
        "svar": "p-gildi er líkurnar á að fá jafnvel eða öfgafyllri niðurstöðu en þá sem fengist hefur, ef núlltilgátan er sönn. Ef p-gildið er minna en α, hafnar maður núlltilgátunni."
    },
    {
        "spurning": "Hvað er áhrifastærð (effect size)?",
        "svar": "Áhrifastærð mælir styrkleika sambandsins eða muninn á milli hópa. Hún gefur til kynna hversu mikill praktískur munur er, óháð marktekt. Dæmi: Cohen's d, Pearson's r."
    },
    {
        "spurning": "Hvað er Cohen's d?",
        "svar": "Cohen's d er mælikvarði á áhrifastærð. Hann gefur til kynna hversu mikill munur er á milli hópa í staðalfrávikum. Dæmi: d = 0.2 (lítil áhrif), d = 0.5 (miðlungs áhrif), d = 0.8 (mikil áhrif)."
    },
    {
        "spurning": "Hvað er núlltilgáta (null hypothesis)?",
        "svar": "Núlltilgátan (H0) er tilgáta sem segir að enginn marktækur munur eða samband sé til staðar. Dæmi: H0: Meðaltal hóps A er jafnt meðaltali hóps B."
    },
    {
        "spurning": "Hvað er gagntilgáta (alternative hypothesis)?",
        "svar": "Gagntilgátan (H1) er tilgáta sem segir að það sé marktækur munur eða samband til staðar. Dæmi: H1: Meðaltal hóps A er ekki jafnt meðaltali hóps B."
    },
    {
        "spurning": "Hvað er gerð I villa (Type I error)?",
        "svar": "Gerð I villa á sér stað þegar núlltilgátunni er hafnað þegar hún er í raun sönn. Líkurnar á að gera gerð I villu eru táknaðar með α."
    },
    {
        "spurning": "Hvað er gerð II villa (Type II error)?",
        "svar": "Gerð II villa á sér stað þegar núlltilgátunni er ekki hafnað þegar hún er í raun ósönn. Líkurnar á að gera gerð II villu eru táknaðar með β."
    },
    {
        "spurning": "Hvað er afköst (power) í tilgátuprófun?",
        "svar": "Afköst (1-β) er líkurnar á að hafna núlltilgátunni þegar hún er í raun ósönn. Afköst eru mælikvarði á næmni prófsins til að greina raunverulegan mun eða samband."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_10.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_10.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_10.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 11')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er parað t-próf (paired t-test)?",
        "svar": "Parað t-próf er notað til að bera saman meðaltöl tveggja tengdra mælinga, t.d. fyrir og eftir inngrip. Dæmi: Kanna áhrif meðferðar á blóðþrýsting fyrir og eftir meðferð."
    },
    {
        "spurning": "Hvað er mismunskor (difference score)?",
        "svar": "Mismunskor er munurinn á tveimur mælingum fyrir sama þátttakanda. Dæmi: Ef einkunn fyrir og eftir inngrip er 80 og 85, þá er mismunskor 85 - 80 = 5."
    },
    {
        "spurning": "Hvað er meðaltal mismunskora (mean difference, MD)?",
        "svar": "Meðaltal mismunskora er meðaltal allra mismunskora í úrtaki. Dæmi: Ef mismunskorin eru 2, 4, 6 þá er meðaltalið (2+4+6)/3 = 4."
    },
    {
        "spurning": "Hvað er staðalfrávik mismunskora (standard deviation of differences)?",
        "svar": "Staðalfrávik mismunskora mælir dreifingu mismunskora í úrtaki. Dæmi: Ef mismunskorin eru 2, 4, 6 og staðalfrávikið er 2, þá er staðalfrávikið mismunskora 2."
    },
    {
        "spurning": "Hvað er staðalvilla mismunskora (standard error of the mean difference)?",
        "svar": "Staðalvilla mismunskora er mat á staðalfráviki meðaltals mismunskora. Dæmi: Ef staðalfrávik mismunskora er 2 og úrtaksstærð er 16 þá er staðalvillan 2/√16 = 0.5."
    },
    {
        "spurning": "Hvað er t-gildi (t-value) í parað t-prófi?",
        "svar": "t-gildi er hlutfall meðaltals mismunskora við staðalvillu mismunskora. Dæmi: Ef meðaltal mismunskora er 4 og staðalvillan er 0.5 þá er t-gildið 4/0.5 = 8."
    },
    {
        "spurning": "Hvað eru frígráður (degrees of freedom, df) í parað t-prófi?",
        "svar": "Frígráður í parað t-prófi eru fjöldi pörunargilda mínus einn. Dæmi: Fyrir 10 pörunargildi er df = 10-1 = 9."
    },
    {
        "spurning": "Hvað er núlltilgáta (null hypothesis) í parað t-prófi?",
        "svar": "Núlltilgátan (H0) í parað t-prófi segir að enginn marktækur munur sé á milli paraðra mælinga. Dæmi: H0: Meðaltal mismunskora er 0."
    },
    {
        "spurning": "Hvað er gagntilgáta (alternative hypothesis) í parað t-prófi?",
        "svar": "Gagntilgátan (H1) í parað t-prófi segir að það sé marktækur munur á milli paraðra mælinga. Dæmi: H1: Meðaltal mismunskora er ekki 0."
    },
    {
        "spurning": "Hvað er p-gildi (p-value) í parað t-prófi?",
        "svar": "p-gildi er líkurnar á að fá jafnvel eða öfgafyllri niðurstöðu en þá sem fengist hefur, ef núlltilgátan er sönn. Ef p-gildið er minna en α, hafnar maður núlltilgátunni."
    },
    {
        "spurning": "Hvað er marktektarstig (significance level, α) í parað t-prófi?",
        "svar": "Marktektarstig (α) er sá þröskuldur sem ákveðinn er fyrirfram og segir til um hversu miklar líkur mega vera á að hafna núlltilgátunni þegar hún er sönn. Algengt marktektarstig er 0.05."
    },
    {
        "spurning": "Hvað er Cohen's d í parað t-prófi?",
        "svar": "Cohen's d er mælikvarði á áhrifastærð í parað t-prófi. Hann gefur til kynna hversu mikill munur er á milli paraðra mælinga í staðalfrávikum. Dæmi: d = 0.2 (lítil áhrif), d = 0.5 (miðlungs áhrif), d = 0.8 (mikil áhrif)."
    },
    {
        "spurning": "Hvað er öryggisbil (confidence interval) fyrir mismunskor í parað t-prófi?",
        "svar": "Öryggisbil er bil sem, með tiltekinni vissu, inniheldur meðaltal mismunskora. Dæmi: Fyrir 95% öryggisbil um meðaltal mismunskora 4 með staðalvillu 0.5 er öryggisbilið 4 ± 1.96*0.5, sem er frá 3.02 til 4.98."
    },
    {
        "spurning": "Hvað er áhrifastærð (effect size) í parað t-prófi?",
        "svar": "Áhrifastærð mælir styrkleika sambandsins eða muninn á milli paraðra mælinga. Hún gefur til kynna hversu mikill praktískur munur er, óháð marktekt. Dæmi: Cohen's d."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_11.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_11.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_11.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 12')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er dreifigreining (ANOVA)?",
        "svar": "Dreifigreining (ANOVA) er tölfræðileg aðferð notuð til að bera saman meðaltöl þriggja eða fleiri hópa til að sjá hvort marktækur munur sé á milli þeirra."
    },
    {
        "spurning": "Hvað er einhliða dreifigreining (one-way ANOVA)?",
        "svar": "Einhliða dreifigreining er notuð til að bera saman meðaltöl þriggja eða fleiri hópa með tilliti til einnar frumbreytu. Dæmi: Ber saman meðaltal prófskora þriggja bekkja."
    },
    {
        "spurning": "Hvað er tvíhliða dreifigreining (two-way ANOVA)?",
        "svar": "Tvíhliða dreifigreining er notuð til að bera saman meðaltöl þriggja eða fleiri hópa með tilliti til tveggja frumbreyta. Dæmi: Ber saman áhrif kyns og aldurs á prófskor."
    },
    {
        "spurning": "Hvað er F-próf (F-test)?",
        "svar": "F-próf er notað í dreifigreiningu til að ákvarða hvort marktækur munur sé á milli hópa. F-gildið er hlutfall milli meðalsummu fervika milli hópa og meðalsummu fervika innan hópa."
    },
    {
        "spurning": "Hvað er frígráður (degrees of freedom, df) í dreifigreiningu?",
        "svar": "Frígráður í dreifigreiningu eru fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Frígráður eru reiknaðar fyrir bæði milli hópa og innan hópa."
    },
    {
        "spurning": "Hvað er meðalsumma fervika (mean square, MS)?",
        "svar": "Meðalsumma fervika er summa fervika deilt með frígráðum. Hún er notuð til að reikna F-gildið í dreifigreiningu. Dæmi: MS_byrgði = SS_byrgði / df_byrgði."
    },
    {
        "spurning": "Hvað er heildardreifing (total variance)?",
        "svar": "Heildardreifing er heildarbreytileiki gagna og er summa fervika milli hópa og fervika innan hópa. Dæmi: SS_heild = SS_byrgði + SS_innan."
    },
    {
        "spurning": "Hvað er áhrifastærð (effect size) í dreifigreiningu?",
        "svar": "Áhrifastærð mælir styrkleika sambandsins eða muninn á milli hópa. Í dreifigreiningu er η² (eta squared) algengasti mælikvarðinn á áhrifastærð."
    },
    {
        "spurning": "Hvað er post-hoc próf?",
        "svar": "Post-hoc próf eru gerð eftir að marktækur munur hefur fundist með dreifigreiningu til að ákvarða nákvæmlega hvaða hópar eru frábrugðnir hver öðrum. Dæmi: Tukey's HSD."
    },
    {
        "spurning": "Hvað er samvirkni (interaction) í dreifigreiningu?",
        "svar": "Samvirkni í dreifigreiningu vísar til þess að áhrif einnar frumbreytu á fylgibreytu séu háð gildum annarrar frumbreytu. Dæmi: Áhrif lyfs á blóðþrýsting geta verið mismunandi eftir kyni."
    },
    {
        "spurning": "Hvað er Levene's próf?",
        "svar": "Levene's próf er notað til að prófa hvort dreifing hópa sé einsleit (homogeneous). Ef prófið er marktækt, þá er forsendan um einsleitni brotin."
    },
    {
        "spurning": "Hvað er Mauchly's próf?",
        "svar": "Mauchly's próf er notað til að prófa hvort fylgni mælinga sé einsleit (sphericity) í endurteknum mælingum. Ef prófið er marktækt, þá er forsendan um sphericity brotin."
    },
    {
        "spurning": "Hvað er Greenhouse-Geisser leiðrétting?",
        "svar": "Greenhouse-Geisser leiðrétting er notuð til að leiðrétta frígráður þegar forsenda um sphericity er brotin í endurteknum mælingum. Hún leiðréttir F-gildið til að draga úr hættu á gerð I villu."
    },
    {
        "spurning": "Hvað er fjölþrepa dreifigreining (MANOVA)?",
        "svar": "MANOVA (multivariate analysis of variance) er útvíkkun á ANOVA sem leyfir fleiri en eina fylgibreytu. Hún er notuð til að kanna hvort hópar séu frábrugðnir í fleiri en einni fylgibreytu samtímis."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_12.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_12.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_12.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 13')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er tvíhliða dreifigreining (two-way ANOVA)?",
        "svar": "Tvíhliða dreifigreining er notuð til að bera saman meðaltöl þriggja eða fleiri hópa með tilliti til tveggja frumbreyta. Dæmi: Ber saman áhrif kyns og aldurs á prófskor."
    },
    {
        "spurning": "Hvað er samvirkni (interaction) í tvíhliða dreifigreiningu?",
        "svar": "Samvirkni vísar til þess að áhrif einnar frumbreytu á fylgibreytu séu háð gildum annarrar frumbreytu. Dæmi: Áhrif lyfs á blóðþrýsting geta verið mismunandi eftir kyni."
    },
    {
        "spurning": "Hvað er aðaláhrif (main effect)?",
        "svar": "Aðaláhrif eru áhrif einnar frumbreytu á fylgibreytu, án tillits til annarra frumbreyta. Dæmi: Áhrif kyns á prófskor, óháð aldri."
    },
    {
        "spurning": "Hvað er F-próf (F-test) í tvíhliða dreifigreiningu?",
        "svar": "F-próf er notað til að ákvarða hvort marktækur munur sé á milli hópa fyrir aðaláhrif og samvirkni. F-gildið er hlutfall milli meðalsummu fervika milli hópa og meðalsummu fervika innan hópa."
    },
    {
        "spurning": "Hvað er meðalsumma fervika (mean square, MS) í tvíhliða dreifigreiningu?",
        "svar": "Meðalsumma fervika er summa fervika deilt með frígráðum. Hún er notuð til að reikna F-gildið í dreifigreiningu. Dæmi: MS_byrgði = SS_byrgði / df_byrgði."
    },
    {
        "spurning": "Hvað eru frígráður (degrees of freedom, df) í tvíhliða dreifigreiningu?",
        "svar": "Frígráður eru fjöldi gilda sem eru frjáls til að breytast þegar verið er að meta breytileika. Frígráður eru reiknaðar fyrir bæði milli hópa og innan hópa."
    },
    {
        "spurning": "Hvað er η² (eta squared) í tvíhliða dreifigreiningu?",
        "svar": "η² (eta squared) er mælikvarði á áhrifastærð í dreifigreiningu. Hún gefur til kynna hlutfall af heildarbreytileikanum sem skýrður er af frumbreytunum. Dæmi: η² = 0.05 (lítil áhrif), η² = 0.1 (miðlungs áhrif), η² = 0.2 (mikil áhrif)."
    },
    {
        "spurning": "Hvað er post-hoc próf í tvíhliða dreifigreiningu?",
        "svar": "Post-hoc próf eru gerð eftir að marktækur munur hefur fundist með dreifigreiningu til að ákvarða nákvæmlega hvaða hópar eru frábrugðnir hver öðrum. Dæmi: Tukey's HSD."
    },
    {
        "spurning": "Hvað er Levene's próf í tvíhliða dreifigreiningu?",
        "svar": "Levene's próf er notað til að prófa hvort dreifing hópa sé einsleit (homogeneous). Ef prófið er marktækt, þá er forsendan um einsleitni brotin."
    },
    {
        "spurning": "Hvað er Mauchly's próf í tvíhliða dreifigreiningu?",
        "svar": "Mauchly's próf er notað til að prófa hvort fylgni mælinga sé einsleit (sphericity) í endurteknum mælingum. Ef prófið er marktækt, þá er forsendan um sphericity brotin."
    },
    {
        "spurning": "Hvað er Greenhouse-Geisser leiðrétting í tvíhliða dreifigreiningu?",
        "svar": "Greenhouse-Geisser leiðrétting er notuð til að leiðrétta frígráður þegar forsenda um sphericity er brotin í endurteknum mælingum. Hún leiðréttir F-gildið til að draga úr hættu á gerð I villu."
    },
    {
        "spurning": "Hvað er fjölþrepa dreifigreining (MANOVA) í tvíhliða dreifigreiningu?",
        "svar": "MANOVA (multivariate analysis of variance) er útvíkkun á ANOVA sem leyfir fleiri en eina fylgibreytu. Hún er notuð til að kanna hvort hópar séu frábrugðnir í fleiri en einni fylgibreytu samtímis."
    },
    {
        "spurning": "Hvað er tölfræðilegt aðfall (statistical regression)?",
        "svar": "Tölfræðilegt aðfall er notað til að lýsa sambandi milli einnar eða fleiri frumbreyta og fylgibreytu með jöfnu. Aðfallsgreining (regression analysis) metur hvernig gildið á fylgibreytu breytist með breytingum á frumbreytum."
    },
    {
        "spurning": "Hvað er þátttakandi (subject) í tilraunum?",
        "svar": "Þátttakandi er einstaklingur sem tekur þátt í rannsókn eða tilraun og veitir gögn. Þátttakendur eru valdir úr þýði til að mynda úrtak."
    },
    {
        "spurning": "Hvað er fylgibreyta (dependent variable)?",
        "svar": "Fylgibreyta er sú breyta sem rannsakendur mæla til að sjá áhrif frumbreytunnar. Dæmi: Í rannsókn á áhrifum lyfs á blóðþrýsting er blóðþrýstingur fylgibreyta."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_13.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_13.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_13.apkg

# %%
import genanki

# Skilgreina Anki deck
my_model = genanki.Model(
  1607392319,
  'Simple Model',
  fields=[
    {'name': 'Question'},
    {'name': 'Answer'},
  ],
  templates=[
    {
      'name': 'Card 1',
      'qfmt': '{{Question}}',
      'afmt': '{{FrontSide}}<hr id="answer">{{Answer}}',
    },
  ])

my_deck = genanki.Deck(
  2059400110,
  'Tölfræði Hugtök - Kafli 14')

# Búa til lista af spurningum og svörum
hugtök = [
    {
        "spurning": "Hvað er fylgni (correlation)?",
        "svar": "Fylgni mælir sambandið milli tveggja breyta. Hún gefur til kynna hvort og hvernig breyturnar tengjast, án þess að segja til um orsakasamhengi. Fylgnistuðullinn (r) getur verið á bilinu -1 til 1."
    },
    {
        "spurning": "Hvað er jákvæð fylgni (positive correlation)?",
        "svar": "Jákvæð fylgni þýðir að þegar ein breyta eykst, eykst hin breytan einnig. Dæmi: Fylgni milli námsárangurs og fjölda klukkustunda sem varið er í nám."
    },
    {
        "spurning": "Hvað er neikvæð fylgni (negative correlation)?",
        "svar": "Neikvæð fylgni þýðir að þegar ein breyta eykst, minnkar hin breytan. Dæmi: Fylgni milli fjölda klukkustunda sem varið er í tómstundir og námsárangur."
    },
    {
        "spurning": "Hvað er núllfylgni (zero correlation)?",
        "svar": "Núllfylgni þýðir að engin tengsl eru milli breytanna. Dæmi: Fylgni milli skónúmera og greindarvísitölu."
    },
    {
        "spurning": "Hvað er fylgnistuðull (correlation coefficient)?",
        "svar": "Fylgnistuðull (r) mælir styrkleika og stefnu fylgninnar milli tveggja breyta. Hann getur verið á bilinu -1 til 1. Jákvæð fylgni hefur jákvætt r-gildi og neikvæð fylgni hefur neikvætt r-gildi."
    },
    {
        "spurning": "Hvað er dreifrit (scatter plot)?",
        "svar": "Dreifrit er myndræn framsetning fylgninnar milli tveggja breyta, þar sem hvert punktapar á grafi táknar gildi breytanna tveggja fyrir einstakt tilfelli."
    },
    {
        "spurning": "Hvað er aðhvarfsgreining (regression analysis)?",
        "svar": "Aðhvarfsgreining er aðferð til að meta sambandið milli frumbreytu og fylgibreytu. Hún gerir kleift að spá fyrir um gildi fylgibreytunnar út frá þekktu gildi frumbreytunnar."
    },
    {
        "spurning": "Hvað er einföld línuleg aðhvarfsgreining (simple linear regression)?",
        "svar": "Einföld línuleg aðhvarfsgreining metur sambandið milli einnar frumbreytu og einnar fylgibreytu með beinni línu. Jafnan fyrir línuna er y = bx + a, þar sem b er hallatala og a er skurðpunktur."
    },
    {
        "spurning": "Hvað er margfeldi aðhvarfsgreining (multiple regression)?",
        "svar": "Margfeldi aðhvarfsgreining metur sambandið milli fleiri en einnar frumbreytu og einnar fylgibreytu. Hún gerir kleift að spá fyrir um fylgibreytuna út frá fleiri en einni frumbreytu samtímis."
    },
    {
        "spurning": "Hvað er hallatala (slope)?",
        "svar": "Hallatala (b) í aðhvarfsgreiningu mælir breytingu á fylgibreytu fyrir hverja einingu breytingar á frumbreytu. Dæmi: Ef hallatalan er 2, þá þýðir það að fyrir hverja einingu aukningu í frumbreytu eykst fylgibreytan um 2 einingar."
    },
    {
        "spurning": "Hvað er skurðpunktur (intercept)?",
        "svar": "Skurðpunktur (a) í aðhvarfsgreiningu er gildi fylgibreytunnar þegar frumbreytan er núll. Dæmi: Ef skurðpunkturinn er 3, þá er gildi fylgibreytunnar 3 þegar frumbreytan er 0."
    },
    {
        "spurning": "Hvað er aðhvarfsjafna (regression equation)?",
        "svar": "Aðhvarfsjafna lýsir línulegu sambandi milli frumbreytu og fylgibreytu. Jafnan er á forminu y = bx + a, þar sem y er fylgibreytan, x er frumbreytan, b er hallatala og a er skurðpunktur."
    },
    {
        "spurning": "Hvað er R² (R-squared)?",
        "svar": "R² (ákvörðunarstuðull) mælir hversu vel aðhvarfslínan útskýrir breytileika fylgibreytunnar. Hann getur verið á bilinu 0 til 1, þar sem 1 þýðir fullkomin útskýring og 0 þýðir engin útskýring."
    },
    {
        "spurning": "Hvað er leifar (residuals)?",
        "svar": "Leifar eru munurinn á raunverulegu gildi fylgibreytunnar og spágildi hennar samkvæmt aðhvarfslínunni. Dæmi: Ef raunverulegt gildi er 10 og spágildið er 8, þá er leifin 2."
    },
    {
        "spurning": "Hvað er F-próf (F-test) í aðhvarfsgreiningu?",
        "svar": "F-próf er notað til að kanna hvort aðhvarfslínan sé marktæk. Það ber saman breytileika útskýrðs breytileika (SS_regression) og breytileika leifa (SS_residual). Ef F-gildið er marktækt, þá er aðhvarfslínan marktæk."
    }
]

# Bæta spurningum og svörum við deckið
for hugtak in hugtök:
    spurning = hugtak["spurning"]
    svar = hugtak["svar"]
    my_note = genanki.Note(
      model=my_model,
      fields=[spurning, svar])
    my_deck.add_note(my_note)

# Vista deckið í skrá
genanki.Package(my_deck).write_to_file('tolfradi_hugtok_kafli_14.apkg')

print("Anki deck búið til og vistað í tolfradi_hugtok_kafli_14.apkg")
# Out:
# Anki deck búið til og vistað í tolfradi_hugtok_kafli_14.apkg
